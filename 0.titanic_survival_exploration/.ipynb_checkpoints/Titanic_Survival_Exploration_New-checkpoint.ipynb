# %%
# # Overview:
# Step 1. Question definition
# Step 2. Acquire train and testing data
# Step 3. Wrangle, prepare, cleanse the data
# Step 4. Analyze, identify patterns, and explore the data
# Step 5. Model, predicit and solve the problem
# Step 6. Visuallize, report, and present the problem solving steps and final solution
# Step 7. Submit the result


# # 7 goals:
# 1) Classifying
# 2) Correlating
# 3) Converting
# 4) Completing
# 5) Correcting
# 6) Creating
# 7) Charting


#data analysis and data wrangling
import pandas as pd
import numpy as np
import random as rnd


# data visualization 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier 
from sklearn.tree import DecisionTreeClassifier

# %%
# Acquire data

train_df = pd.read_csv('TitanicFromKaggle/notebooks-master/input/train.csv')
test_df = pd.read_csv('TitanicFromKaggle/notebooks-master/input/test.csv')
combine = [train_df, test_df]

# print combine

# %%
# Describe data

print(train_df.columns.values)
print(test_df.columns.values)
# Out:
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']
# ['PassengerId' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch' 'Ticket' 'Fare'
#  'Cabin' 'Embarked']

# %%
# categorical: survived, sex, embarked

# ordinal: Pclass

# numerical: age, fare

# descrete: SibSp, Parch

# %%
# preview of the data

train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# features are Mixed data type: 
# -Ticket (Numberical and alphanumberic data type)
# -Cabin (alphanumeric)


# features may contain errors or typos:
# -Name (titles, brackets, quotes)


# features may contain blank, null or empty values:
# -Cabin
# -Age
# -Embarked
# need to be corrected


# data types with various features
# -7 features are integer or float
# -5 feature are strings

# %%
train_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train_df.info()
print('~'*40)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# ...

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# percentile=

# %%
# Think:

# What is the distribution of numerical feature values across the samples?
# (This will tell us more about training dataset)

# - total samples:891, 40% out of 2224
# - survival is a categorical feature with 0 or 1 values
# - sample survival rate:38%, actual survival rate:32%
# - >75% passengers did not travel with parents or children
# - nearly 30% of the passengers had siblings and/or spouse abroad
# -

# %%
train_df.describe(include=['O'])
# Out:
#                              Name   Sex    Ticket        Cabin Embarked
# count                         891   891       891          204      889
# unique                        891     2       681          147        3
# top     Graham, Mr. George Edward  male  CA. 2343  C23 C25 C27        S
# freq                            1   577         7            4      644

# %%
# What is the distribution of the categorical feature?
# 1. Names are uniqte across the dataset (count = unique = 891)
# 2. Male = 577
# 3. Cabin values have several duplicates across the samples, and some passengers share a cabine
# 4. Embarked has 3 values, and most of passengers land in port "S"
# 5. Ticket values have many duplicates, hige ratio, 681/891. Ticket type CA2343 appear most frequently

# %%
# Assumptions:

# 1) Correlating:
# We want to know how well does each feature correlate with Survival.
# Do this early in the project and match these quick correlations with modelled correlations later in the project.


# 2) Completing:
# - Complete the age feature as it is definitely correlated to survival.
# - Complete the emarked feature as it may also correlated with survival or another important feature. 


# 3) Correcting:
# - Ticket feature. Drop it. It contains high ration of duplicates (22%), 
# so it there may not be a correlation between ticket and survival.
# - Cabin feature. Drop it. Highly incomplete and contains many null values.
# - Passengeerld feature. Drop it. It doesn't contribute to survival.


#4) Creating:
# - Create a new feature called "Family" based on Parch and SibSp to get the total count of family member on board.
# - Engineer the Name feature to extract Title as new feature.
# - Create a new feature for Age bands. It will turn a continous numerical feature into a ordinal categorial feature. 
# - Create a Fare range. 


# 5) Classifying:
# - Add our assumptions:
# - 1. Women (Sex == femal) were more likely to have survived
# - 2. Children (Age < ?) were more likely to have survived
# - 3. The upper-class passenger (Pclass == 1) were more likely to have survived

# %%
#Step 4: Analyze the data
# To confirm our assumptions, we can quickly analyze our feature correlations by pivoting features against each other.
# We can only do it now. Why?
# - Features at this stage don't have any empty values/
# - Features at his stage are categorical(sex), ordinal(Pclass), or discrete(SibSp, Parch) type.

# Features:
# Pclass: There is significant correlation (>0.5) among pclass == 1 and survived (classifying #3). So, add this to our model.
# Sex: When sex == female, survival rate = 74% (Classifying #1)
# SibSp and Parch: These features have zero correlations for certain values. Not now.

# %%
# # Survived and Pclass
# pivot = train_df[['Pclass', 'Survived']].groupby(['Pclass'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# print pivot

train_df[['Pclass', 'Survived']].groupby(['Pclass'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
# Play with it.
# train_df[['Pclass', 'Age']]

# %%
# Survived and Sex
train_df[['Sex', 'Survived']].groupby(['Sex'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
# Survived and SibSp
train_df[['SibSp', 'Survived']].groupby(['SibSp'], as_index = False).mean().sort_values(by = 'SibSp', ascending = False)
# Out:
#    SibSp  Survived
# 6      8  0.000000
# 5      5  0.000000
# 4      4  0.166667
# 3      3  0.250000
# 2      2  0.464286
# 1      1  0.535885
# 0      0  0.345395

# %%
# Survied and Parch
train_df[['Parch', 'Survived']].groupby(['Parch'], as_index = False).mean().sort_values(by = 'Parch', ascending = False)
# Out:
#    Parch  Survived
# 6      6  0.000000
# 5      5  0.200000
# 4      4  0.000000
# 3      3  0.600000
# 2      2  0.500000
# 1      1  0.550847
# 0      0  0.343658

# %%
# Step: Analyze by Visualizing Data

# correlating numerical features
# What are correlations between numerical features and solution goal(Survived)?
# Use historgram

g = sns.FacetGrid(train_df, col = 'Survived')
g.map (plt.hist, 'Age', bins = 20)
