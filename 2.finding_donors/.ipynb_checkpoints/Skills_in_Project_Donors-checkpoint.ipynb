# %%
import numpy as np
import pandas as pd
import time as time
from IPython.display import display
import visuals as vs

% matplotlib inline

data = pd.read_csv('census.csv')

# %%
display(data)
# Out:
#        age          workclass education_level  education-num  \
# 0       39          State-gov       Bachelors           13.0
# 1       50   Self-emp-not-inc       Bachelors           13.0
# 2       38            Private         HS-grad            9.0
# 3       53            Private            11th            7.0
# 4       28            Private       Bachelors           13.0
# 5       37            Private         Masters           14.0
# 6       49            Private             9th            5.0
# 7       52   Self-emp-not-inc         HS-grad            9.0
# 8       31            Private         Masters           14.0
# 9       42            Private       Bachelors           13.0
# 10      37            Private    Some-college           10.0
# 11      30          State-gov       Bachelors           13.0
# 12      23            Private       Bachelors           13.0
# 13      32            Private      Assoc-acdm           12.0
# ...

# %%
display(data.head(n=3))
# Out:
#    age          workclass education_level  education-num       marital-status  \
# 0   39          State-gov       Bachelors           13.0        Never-married
# 1   50   Self-emp-not-inc       Bachelors           13.0   Married-civ-spouse
# 2   38            Private         HS-grad            9.0             Divorced
#
#            occupation    relationship    race    sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White   Male        2174.0
# 1     Exec-managerial         Husband   White   Male           0.0
# 2   Handlers-cleaners   Not-in-family   White   Male           0.0
#
#    capital-loss  hours-per-week  native-country income
# 0           0.0            40.0   United-States  <=50K
# 1           0.0            13.0   United-States  <=50K
# 2           0.0            40.0   United-States  <=50K

# %%
data.head(3)
# Out:
#    age          workclass education_level  education-num       marital-status  \
# 0   39          State-gov       Bachelors           13.0        Never-married
# 1   50   Self-emp-not-inc       Bachelors           13.0   Married-civ-spouse
# 2   38            Private         HS-grad            9.0             Divorced
#
#            occupation    relationship    race    sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White   Male        2174.0
# 1     Exec-managerial         Husband   White   Male           0.0
# 2   Handlers-cleaners   Not-in-family   White   Male           0.0
#
#    capital-loss  hours-per-week  native-country income
# 0           0.0            40.0   United-States  <=50K
# 1           0.0            13.0   United-States  <=50K
# 2           0.0            40.0   United-States  <=50K

# %%
data.shape # dimensionality #this data frame is a 2-D # so that why (x, y)
# Out:
# (45222, 14)

# %%
data.shape[0]
# Out:
# 45222

# %%
# How to find out the total of records?
n_records = data.shape[0]    #What I did: n_records = len(data)
print n_records
# Out:
# 45222

# %%
# How to find out the total features?
n_features = data.shape[1]
print n_features
# Out:
# 14

# %%
data.shape[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-a35554d428de> in <module>()
# ----> 1 data.shape[2]
#
# IndexError: tuple index out of range

# %%
# How to find total number of people who earn >50K
n_greater_50K = data[(data.income == '>50K')].shape[0]



print n_greater_50K
# Out:
# 11208

# %%
data.income == '>50K'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18        True
# 19        True
# 20       False
# 21       False
# 22       False
# 23       False
# 24        True
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 45192    False
# 45193    False
# 45194     True
# 45195     True
# 45196    False
# 45197     True
# 45198     True
# 45199    False
# 45200    False
# 45201    False
# 45202    False
# 45203    False
# 45204     True
# 45205    False
# 45206    False
# 45207    False
# 45208    False
# 45209    False
# 45210    False
# 45211    False
# 45212    False
# 45213    False
# 45214    False
# 45215    False
# 45216    False
# 45217    False
# 45218    False
# ...

# %%
sum(data.income == '>50K')
# Out:
# 11208

# %%
sum(data['income'] == '>50K')
# Out:
# 11208

# %%
data[(data.income == '>50K')]   # same as: data[data.income == '>50K']
# Out:
#        age          workclass education_level  education-num  \
# 7       52   Self-emp-not-inc         HS-grad            9.0
# 8       31            Private         Masters           14.0
# 9       42            Private       Bachelors           13.0
# 10      37            Private    Some-college           10.0
# 11      30          State-gov       Bachelors           13.0
# 18      43   Self-emp-not-inc         Masters           14.0
# 19      40            Private       Doctorate           16.0
# 24      56          Local-gov       Bachelors           13.0
# 42      57        Federal-gov       Bachelors           13.0
# 48      47            Private     Prof-school           15.0
# 49      50        Federal-gov       Bachelors           13.0
# 51      43            Private    Some-college           10.0
# 58      42            Private       Doctorate           16.0
# 62      53            Private         HS-grad            9.0
# ...

# %%
# This causes problem: 'tuple' object is not callable
data[(data.income == '>50K')].shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-81abfbc27bdd> in <module>()
#       1 # This causes problem: 'tuple' object is not callable
# ----> 2 data[(data.income == '>50K')].shape()
#
# TypeError: 'tuple' object is not callable

# %%
# I just created new 2-D dataframe
data[(data.income == '>50K')].shape
# Out:
# (11208, 14)

# %%
# Total number of people who earn more than 50K
n_greater_50K = data[(data.income == '>50K')].shape[0]

print n_greater_50K
# Out:
# 11208

# %%
data['income']
# Out:
# 0        <=50K
# 1        <=50K
# 2        <=50K
# 3        <=50K
# 4        <=50K
# 5        <=50K
# 6        <=50K
# 7         >50K
# 8         >50K
# 9         >50K
# 10        >50K
# 11        >50K
# 12       <=50K
# 13       <=50K
# 14       <=50K
# 15       <=50K
# 16       <=50K
# 17       <=50K
# 18        >50K
# 19        >50K
# 20       <=50K
# 21       <=50K
# 22       <=50K
# 23       <=50K
# 24        >50K
# 25       <=50K
# 26       <=50K
# 27       <=50K
# 28       <=50K
# 29       <=50K
#          ...
# 45192    <=50K
# 45193    <=50K
# 45194     >50K
# 45195     >50K
# 45196    <=50K
# 45197     >50K
# 45198     >50K
# 45199    <=50K
# 45200    <=50K
# 45201    <=50K
# 45202    <=50K
# 45203    <=50K
# 45204     >50K
# 45205    <=50K
# 45206    <=50K
# 45207    <=50K
# 45208    <=50K
# 45209    <=50K
# 45210    <=50K
# 45211    <=50K
# 45212    <=50K
# 45213    <=50K
# 45214    <=50K
# 45215    <=50K
# 45216    <=50K
# 45217    <=50K
# 45218    <=50K
# ...

# %%
data('income', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-0b59ff6fe431> in <module>()
# ----> 1 data('income', axis = 1)
#
# TypeError: 'DataFrame' object is not callable
